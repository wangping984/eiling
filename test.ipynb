# %%
import pandas as pd
import yfinance as yf


gzmt = yf.Ticker('600519.ss')
info = gzmt.info

# %%
gzmt.earnings
# Out:
#           Revenue     Earnings
# Year
# 2017  58218446218  27079360261
# 2018  73639749745  35203625271
# 2019  85429865919  41206471020
# 2020  94915380916  46697285434

# %%
# gzmt.get_balance_sheet()
gzmt.get_balancesheet()
# Out:
#                                     2020-12-31    2019-12-31    2018-12-31  \
# Intangible Assets                 4.817171e+09  4.728027e+09  3.499175e+09
# Capital Surplus                   1.374964e+09  1.374964e+09  1.374964e+09
# Total Liab                        4.567513e+10  4.116599e+10  4.243819e+10
# Total Stockholder Equity          1.613227e+11  1.360103e+11  1.128386e+11
# Minority Interest                 6.397948e+09  5.866030e+09  4.569924e+09
# Deferred Long Term Liab           1.477215e+08  1.582843e+08  1.684147e+08
# Other Current Liab                3.488785e+10  3.050945e+10  3.297695e+10
# Total Assets                      2.133958e+11  1.830424e+11  1.598467e+11
# Common Stock                      1.256198e+09  1.256198e+09  1.256198e+09
# Other Current Assets              9.251731e+08  1.570382e+09  1.322463e+09
# Retained Earnings                 1.586969e+11  1.333864e+11  1.102145e+11
# ...
